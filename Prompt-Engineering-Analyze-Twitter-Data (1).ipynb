# %% [markdown]
# # Prompt Engineering: Use OpenAI to Analyze Twitter Data
# This is a simple tutorial teaching prompt engineering basics and analyzing Twitter data with OpenAI large language models (LLM).
# Please purchase an [OpenAI API](https://openai.com/index/openai-api/) and store it in a safe place. This tutorial uses [AWS Secretes Manager](https://aws.amazon.com/secrets-manager/) to store the API keys.

# %% [markdown]
# ## Large Language Model Basics
# LLM repeatable predicts the next world using supervised learning. To predict the following sentence:
#
# `Learning data science in the cloud with AI`
#
# A model needs to learn to predict the following steps:
#
# |Input|Output|
# |:---|---|
# |Learning data science |in |
# |Learning data science in |the |
# |Learning data science in the |cloud |
# |Learning data science in the cloud |with |
# |Learning data science in the cloud with |AI|
#
# To train an LLM model:
# 1. Training a base LLM model on a large amount of training data to predict the next word
# 2. Fine-tune on examples where outputs follow instructions in the input
# 3. Human rates quality of different LLM outputs
# 4. Tune LLM to generate outputs with higher rates using RLHF (Reinforcement learning from human feedback)

# %% [markdown]
# ## Set up OpenAI Models

# %% [markdown]
# Load the API keys with AWS Secrets Manage Function

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %% [markdown]
# ## Install Python libraries.
#
# - pymongo: manage the MongoDB database
# - openai: call the OpenAI APIs.

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.70.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Downloading openai-1.70.0-py3-none-any.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.1/599.1 kB 34.1 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
# Installing collected packages: jiter, distro, openai
# Successfully installed distro-1.9.0 jiter-0.9.0 openai-1.70.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.3 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load the OpenAI API key and define a `openai_help` function.

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

def openai_help(messages, model=model, temperature =temperature ):
    messages = messages
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature

    )
    return response.choices[0].message.content

# %% [markdown]
# Temperature:
# - Low temperature: always choose the most likely response, reliable, predictable responses
# - High temperature: diverse responses, more creative responses
#
# Tokens and Models:
# - LLM predicts tokens, which are commonly occurring sequences of characters.
# - One token is about four characters in English, and 100 tokens are roughly 75 words. Check [token estimate](https://platform.openai.com/tokenizer).
# - Different models can process various amounts of tokens at different performance levels and costs. Check [OpenAI models](https://platform.openai.com/docs/models) for more details.
#
# Roles:
# - system: specify the overall tone or behavior of the assistant
# - user: instruction given to the LLM
# - assistant: LLM responded content, we also can provide content in few-shot promoting or histories of conversations

# %% [markdown]
# A simple example using [gtp-4o](https://platform.openai.com/docs/models/gpt-4o) and temperature 0.

# %%
messages = [{"role": "user", "content": "What is the capital of USA"}]

print(openai_help(messages))
# Out:
# The capital of the United States is Washington, D.C.

# %% [markdown]
# Add a system message asking LLM to act as a high school teacher with different temperatures.

# %%
messages = [
    {"role": "system", "content": "use tone as a high school teacher"},
    {"role": "user", "content": "What is the capital of USA"}
    ]

print(openai_help(messages, temperature = 0.8))
# Out:
# The capital of the United States is Washington, D.C. It's an important city not just because it's the seat of the federal government, but also because it's rich in history and culture. If you ever have the chance to visit, the National Mall, museums, and historical monuments are definitely worth exploring.

# %% [markdown]
# Add assistant messages to teach LLM what `##` is.

# %%
messages = [
    {"role": "user", "content": "What is 1##1"},
    {"role": "assistant", "content": "it is 11"},
    {"role": "user", "content": "What is 2##2"},
    {"role": "assistant", "content": "it is 22"},
    {"role": "user", "content": "What is 3##3"},
    ]
print(openai_help(messages))
# Out:
# It is 33.

# %% [markdown]
# ## Prompt Engineering Principles
# - Use delimiters to separate different parts of a prompt to provide clear instructions and prevent prompt injections.
# - Structure outputs in JSON documents or other formats to use the outputs in subsequent steps
# - Few-shot promoting: provide successful examples of a task and then ask the model to perform a similar task.
# - Chain of thought reasoning: request a series of reasoning steps in prompts to help the model achieve correct answers
# - Chain of prompts: split a task into multiple prompts where each prompt can focus on a sub-task at a time and take different actions at different stages. It saves tokens, is easier to test, can involve human input, or use external tools.
# - Interactive process
#   1. Try something first
#   2. Analyses the result, identify errors, and redefine the prompt
#   3. Test the prompts with different datasets

# %% [markdown]
# An example using delimiters, structured output and few-shot promoting:

# %%
delimiter = '###'
sentence1 = 'I love cat.'
sentence2 = 'I love dog.'
messages = [
    {"role": "system", "content": f"""analyze the sentiment in a sentence delimitered by {delimiter},
                                     return the result as a JSON document"""},
    {"role": "user", "content": f"{delimiter}{sentence1}{delimiter}"},
    {"role": "assistant", "content": "{sentiment:positive}"},
    {"role": "user", "content": f"{delimiter}{sentence2}{delimiter}"}
    ]

print(openai_help(messages))
# Out:
# { "sentiment": "positive" }

# %% [markdown]
# ## Analyze Twitter data

# %% [markdown]
# ### Connect to the MongoDB cluster

# %%
import pymongo
from pymongo import MongoClient
mongodb_connect = get_secret('mongodb')['connection_string']

mongo_client = MongoClient(mongodb_connect)
db = mongo_client.demo # use or create a database named demo
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("tweet.id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'tweet.id_1'

# %% [markdown]
# ### Extract Tweets

# %%
filter={

    
}
project={
    'tweet.text': 1, 
    'tweet.id': 1
}
#rename the client to mongo_client
result = mongo_client['demo']['tweet_collection'].find(
  filter=filter,
  projection=project
)

# %%
tweet_data = []
for tweet in result:
    tweet_data.append(tweet['tweet']['text'])

print(tweet_data)
# Out:
\n\nTHIS is why they’re banning…', 'RT @CilComLFC: 🚨BREAKING: Marine Le Pen has been sentenced to 4 years in Jail and BANNED from holding Public Office for 5 years.\n\nThe ban d…', 'RT @2Halumi: - Fillon a été empêché\n- Sarkozy est harcelé\n- C8 exclu de la TNT\n- Zemmour harcelé judiciairement \n - Marine Le Pen inéligibl…', 'RT @philippeherlin: «Comment je suis passée de consultante chez E&amp;Y à magistrate aux affaires familiales en regardant Eva Joly à la télé»…', 'RT @PopCrave: French far right leader Marine Le Pen has been found guilty of embezzling European Union funds. https://t.co/DlMrZS5ZQi', 'RT @CerfiaFR: 🚨🇫🇷 FLASH | "Non", Marine Le Pen n’appelle pas à la grâce présidentielle d’Emmanuel Macron. https://t.co/aEf9CJKWOb', "RT @YourAnonCentral: Russia, completely unprompted, has condemned the conviction of Marine Le Pen in France claiming it 'violates democrati…", 'RT @PeterSweden7: BREAKING: Ri ...

# %%
print('Number of tweets: ',len(tweet_data))
# Out:
# Number of tweets:  100

# %% [markdown]
# ### Summarization
# - Analyze election tweets with delimiters
# - Change the size of the summarization
# - Summarize tweets and focus on different perspectives.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter}"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets discuss the recent conviction of French far-right leader Marine Le Pen for embezzling European Union funds, resulting in a four-year prison sentence and a five-year ban from holding public office. The decision has sparked significant controversy and debate, with some viewing it as a political move against right-wing figures. Various international figures, including Russia and Italy's Deputy Prime Minister, have criticized the ruling, claiming it undermines democratic norms. Supporters of Le Pen argue that the verdict is unjust and politically motivated, while others emphasize the importance of accountability for financial misconduct.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    limit the summary to 20 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# Marine Le Pen convicted of embezzlement, banned from elections, sparking international reactions and claims of political motives.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    focus on how people discuss motivation,
                                    limit the summary to 50 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets discuss motivation in the context of political actions and consequences, highlighting how leaders like Marine Le Pen face legal challenges when opposing the establishment. The narrative suggests that such actions are politically motivated, aiming to suppress dissent and maintain control, sparking debates on democracy and justice.

# %% [markdown]
# ### Moderation
# - Iterate each tweet and use the [moeration endpoint](https://platform.openai.com/docs/api-reference/moderations) to identify flagged tweets
# - Print flagged tweets

# %%
def flag_help(tweet):
    response = client.moderations.create(
        model="omni-moderation-latest",
        input=tweet)

    if response.results[0].flagged:
        print('===')
        cat_dict = response.results[0].categories.to_dict()
        for cat in cat_dict.keys():
            if cat_dict.get(cat):
                print (cat)
                print(tweet)

# %%
for tweet in tweet_data:
    flag_help(tweet)
# Out:
# ===
# harassment
# RT @Benjam1Lucas: Marine Le Pen est une délinquante.
# ===
# harassment
# RT @PatrioteEngager: #RN  C est cette Immonde femme la juge #Macroniste Bénédicte de Perthuis qui a rendu #ineligible  Marine Le Pen  Cette…
# ===
# harassment
# RT @LeLapinDuFutur: Marine Le Pen inéligible le lendemain de la fin du ramadan où l'on a pu voir des millions de musulmans prier dans la ru…
# ===
# harassment
# RT @Benramine_: Phillipe Poutou ce visionnaire il avait raison sur Fillion , sur Marine Le pen quel goat https://t.co/FEeEs85w0i
# ===
# harassment
# RT @FredGaulois: Gilles Bouleau face à  Marine Le Pen est juste insupportable, on voit bien toute sa haine, alors qu il ferme sa gueule fac…

# %% [markdown]
# ### Transforming
# - Translating to a different language
# - Transform tones, such as formal vs. informal.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""translate the tweets delimited by {delimiter} into Chinese"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# RT @Artemisfornow: 全球主义——每一个敢于挑战体制的领导人都会面临相同的命运：起诉、监禁或流亡。…
# RT @MrPitbull07: @MLP_officiel 当民主未能坚持其自身价值时，它就会变成伪装成正义的暴政。
#
# 玛丽娜·勒庞 w…
# RT @morandiniblog：紧急 - 玛丽娜·勒庞在TF1上说：“我不相信呼叫的日期，因为这不是我决定的……”
# RT @HansMahncke: 对玛丽娜·勒庞的政治迫害比你想象的还要严重。媒体急切地称之为“挪用公款”的事情其实根本不是这样……
# 转发 @tavoliakys：玛丽娜·勒庞不符合法国总统选举的资格 https://t.co/3HofIZlOWm
# RT @bennyjohnson: 右翼法国政治家玛丽娜·勒庞因贪污罪被判有罪。
#
# 她五年内不能参选……
# RT @Inevitablewest: 🚨突发新闻：意大利副总理：
#
# “禁止玛丽娜·勒庞是布鲁塞尔的宣战声明。”
#
# 欧盟不知道什么是……
# RT @PGKroeger: 勒庞要求对那些在财务上作弊的政客进行终身排除 🇫🇷🇪🇺💶🤪 https://t.co/UrXJE6W6Te
# RT @Ilangabet: 线索：玛丽娜·勒庞被判处4年监禁和5年不得参选，并立即执行。
#
# 国民阵线将发起一项……
# RT @EvaVlaar: 针对欧洲右翼的法律战正在被提升到一个全新的水平。
#
# 玛丽娜·勒庞 @MLP_officiel 已被判决…
# RT @BRICSinfo: 最新消息：🇷🇺🇫🇷 俄罗斯称对玛丽娜·勒庞的定罪“违反了民主规范。” https://t.co/tT8NEUd7zZ
# RT @AdresanSoso: 玛丽娜·勒庞可能面临监禁和丧失参选资格，因为她涉嫌从欧盟挪用400万欧元。…
# RT @stillgray: 玛丽娜·勒庞刚刚被判处两年监禁。这太疯狂了。https://t.co/l71TDXQZ4j
# RT @CilComLFC: 法国人民热爱玛丽娜·勒庞，并要求立即推翻她的“有罪”判决！🇫🇷🇫🇷🇫🇷 https://t.co/ct…
# RT @PopCrave: 法国极右翼领导人玛丽娜·勒庞被判定挪用欧盟资金罪名成立。https://t.co/DlMrZS5ZQi
# RT @La_SER: 🔴 最新消息 | 法国极右翼的玛丽娜·勒庞和其他8名欧洲议会议员因挪用公共资金被判有罪
# http…
# RT @L_Wcrdt: « 我们对你们实施的是你们昨天所主张的…… »
#
# Gilles Bouleau 在面对玛丽娜·勒庞时直言不讳。https://t.co/kn5NWbvc…
# RT @Inevitablewest: 🚨突发新闻：俄罗斯发表声明：
#
# “对玛丽娜·勒庞的定罪违反了民主规范。” https://t.co/lq13…
# RT @_Brick_Block_: 玛丽娜·勒庞因挪用公款被判有罪：被判定为不具备参选资格。🤭#是个神枪手 https:/…
# 转发 @knafo_sarah: 他们敢于行动。
#
# 很多人昨天还在说：“法官们绝对不敢。” 法官们敢于一切，因为阶级...
# RT @MarioNawfal: 🚨🇮🇹🇫🇷意大利副总理对玛丽娜·勒庞的判决感到愤怒
#
# 马泰奥·萨尔维尼：
#
# “那些害怕选民判断的人往往…”
# RT @liz_churchill10: 这是玛丽娜·勒庞赢得第一轮选举，因为法国明确拒绝了世界经济论坛的马克龙。
#
# 这就是他们禁止的原因…
# RT @CilComLFC: 🚨突发新闻：玛丽娜·勒庞被判处4年监禁，并被禁止5年内担任公职。禁令…
# RT @2Halumi：- 菲永被阻止了 - 萨科齐被骚扰 - C8被排除在TNT之外 - 泽穆尔被司法骚扰 - 玛丽娜·勒庞失去资格…
# RT @philippeherlin: «我如何从安永的顾问变成家庭事务法官，看着电视上的Eva Joly»…
# RT @PopCrave: 法国极右翼领导人玛丽娜·勒庞被判挪用欧盟资金罪名成立。https://t.co/DlMrZS5ZQi
# RT @CerfiaFR: 🚨🇫🇷 快讯 | “不”，玛丽娜·勒庞并未呼吁给予埃马纽埃尔·马克龙总统特赦。https://t.co/aEf9CJKWOb
# RT @YourAnonCentral: 俄罗斯在没有任何提示的情况下谴责了法国对玛丽娜·勒庞的定罪，称其“违反民主…
# RT @PeterSweden7: 突发新闻：右翼的玛丽娜·勒庞刚刚被禁止参加民主选举。
#
# 这意味着她将无法…
# RT @COMPACTMagazin: 严厉判决：勒庞不得再参加选举 🇫🇷⚖️
#
# 🟥 法国右翼政治家玛丽娜·勒庞被禁止…
# RT @MedvedevRussiaE: 在今天的法院裁决之后，似乎只有俄罗斯哥萨克才能像他们在3月那样恢复法国的自由……
# RT @CilComLFC: 法国人民热爱玛丽娜·勒庞，并要求立即推翻她的“有罪”判决！ 🇫🇷🇫🇷🇫🇷 https://t.co/ct…
# RT @JordanFlrtn: 有些小工人除了投票给玛丽娜·勒庞以外，别无选择，只能希望获得最低限度的经济生存和……
# RT @AlertesInfos: 🚨🇫🇷🇷🇺⚖️ 紧急消息 - 德米特里·梅德韦杰夫将玛丽娜·勒庞的审判比作法国的自由侵蚀。他提到31…
# 转发 @knafo_sarah: 他们敢于行动。
#
# 很多人昨天还在说：“法官们绝对不敢。” 法官们什么都敢，因为阶级...
# RT @Benjam1Lucas: 玛丽娜·勒庞是个罪犯。
# RT @stillgray: 玛丽娜·勒庞刚刚被判处两年监禁。这太疯狂了。https://t.co/l71TDXQZ4j
# RT @Artemisfornow: 全球主义——每一个敢于挑战现有体制的领导人都面临相同的命运：起诉、监禁或流亡。…
# RT @BRICSinfo: 最新消息：🇷🇺🇫🇷 俄罗斯称对玛丽娜·勒庞的定罪“违反了民主规范。” https://t.co/tT8NEUd7zZ
# RT @TimesAlgebraIND: 重大突发新闻 🚨 法国的民主非正式结束！！
#
# 法国法院判处极右翼的玛丽娜·勒庞4年……
# RT @reitschuster: https://t.co/0hTOTmUkd1
# 玛丽娜·勒庞在法国不再被允许参选。这是一个警报信号：民主正在……
# RT @EvaVlaar: 针对欧洲右翼的法律战正在被提升到一个全新的水平。
#
# 玛丽娜·勒庞 @MLP_officiel 已被判决…
# RT @oida_grantler: 对玛丽娜·勒庞的判决是欧盟终结的开始吗？https://t.co/ZOckWApq6L
# RT @RadioRadioWeb: 🚨 玛丽娜·勒庞被判不合格，@boni_castellane 的反应 ▷ “现在你们还记得布雷顿的话吗？”
#
# 干预…
# RT @Ilangabet: 玛丽娜·勒庞的支持者：
#
# 弗拉基米尔·普京
# 维克多·欧尔班
# 埃隆·马斯克
#
# 就差金正恩谴责侵犯……
# RT @MAnthoParis: 玛丽娜·勒庞在TF1上表示：
# “我将永远站在法国人民这一边。
# 有数百万人信任我，…”
# RT @banalreis: 🇫🇷 在民调中领先的勒庞将无法参加2027年的选举。
#
# 法国法院对玛丽娜·勒庞处以政治禁令处罚…
# 转发 @humanite_fr: 4月1日的《人道报》：玛丽娜·勒庞，双手肮脏，低头
#
# 📰 https://t.co/HlQqUuQ1TE https://t.co/X7gUs0l6EZ
# RT @laverdad_es: 玛丽娜·勒庞被禁止五年，无法在2027年竞选法国总统 https://t.co/vbokPj0BtX
# RT @CilComLFC: 法国人民热爱玛丽娜·勒庞，并要求立即推翻她的“有罪”判决！ 🇫🇷🇫🇷🇫🇷 https://t.co/ct…
# 抱歉，我无法协助翻译该内容。
# RT @stillgray: JD Vance 对欧洲的看法是正确的，尤其是今天法国的发展，玛丽娜·勒庞被判刑……
# RT @LaureLavalette: Perthuis的法官解释说存在“再犯的风险”。玛丽娜·勒庞不再是欧洲议会议员，不是...
# 转发 @Bruno_Attal_: 对玛丽娜·勒庞的判决确实是政治性的！
#
# 判决玛丽娜·勒庞的法官是贝内迪克特·德·佩尔蒂斯…
# RT @PeterSweden7: 保守派的玛丽娜·勒庞曾是下届法国总统选举的热门人选。
#
# 法院刚刚判决她……
# RT @BRICSinfo: 最新消息：🇮🇹 意大利副总理表示，“禁止玛丽娜·勒庞是布鲁塞尔的宣战声明。” https://t.co/q…
# RT @RMXnews: 突发新闻：
#
# 今天标志着法国民主的终结。
#
# 一名法官裁定玛丽娜·勒庞无资格参加20…年的总统竞选。
# RT @liz_churchill10: 法国民粹主义领袖玛丽娜·勒庞被判处4年监禁。
#
# “那些与伊斯兰主义意识形态有关的人…”
# RT @CNEWS: «如果这件事发生在让-吕克·梅朗雄身上，我们同样会感到震惊», 记者Geoffroy Lejeune在回应时表示…
# RT @supermegadrivin: 玛丽娜·勒庞离开法庭的场景直接成为历史上最著名的愤怒离场之一
# 转发 @TolergueNina: 我们提醒那些理解能力差的人，如果玛丽娜·勒庞没有挪用公款，就不会有审判和……
# RT @Kevin_Maguire: 无法无天的全球极右翼和极端右翼无疑会假装玛丽娜·勒庞的判决是自德雷福斯事件以来最严重的丑闻……
# 转发 @CH_Gallois：通过玛丽娜·勒庞，他们想要压制的是法国人民。
#
# #拯救民主 #我支持玛丽娜 https:…
# RT @actuetpolitique: 🚨‼️🇫🇷🇺🇸 紧急 - 埃隆·马斯克对玛丽娜·勒庞的判决作出反应：“当激进左派无法赢得…”
# RT @ZeClint: 如果玛丽娜·勒庞违法了，我支持法律制裁……问题是其他政党也做了同样的事情……
# RT @Inafr_officiel: 🔴 "除了国民阵线，所有人都从公款中偷钱了。"
#
# 玛丽娜·勒庞刚刚被判处5…
# RT @CNEWS：哲学家米歇尔·翁弗雷将玛丽娜·勒庞的不可选举刑罚与关闭C8频道和抵制某些游戏进行比较…
# RT @liz_churchill10: 这是玛丽娜·勒庞赢得第一轮选举，因为法国明确拒绝了世界经济论坛的马克龙。
#
# 这就是他们禁止的原因…
# @FouratiJerbi 确定吗？
# https://t.co/KY3nozVNpX
# RT @2Halumi: - 菲永被阻止
# - 萨科齐被骚扰
# - C8被排除在TNT之外
# - 泽穆尔被司法骚扰
# - 玛丽娜·勒庞失去资格…
# RT @BonneDroite: 说得好：@tegnererik 在6个月前就预测了玛丽娜·勒庞将失去参选资格。https://t.co/AHYdYtiQ2r
# RT @2Halumi：- 菲永被阻止了 - 萨科齐被骚扰 - C8被排除在地面数字电视之外 - 泽穆尔被司法骚扰 - 玛丽娜·勒庞失去资格…
# RT @AudeJavel79: 国民联盟：司法太宽松了😡
#
# “玛丽娜·勒庞被判刑。”
#
# 国民联盟：司法太严厉了😡
# RT @CilComLFC: 🚨突发新闻：玛丽娜·勒庞被判处4年监禁，并被禁止5年内担任公职。禁令…
# RT @Frontieresmedia: « 伊娃·乔利改变了我的命运 »
#
# 判决玛丽娜·勒庞有罪的法官贝内迪克特·德·佩尔蒂斯讲述了她的故事…
# RT @BFMTV: “我是玛丽娜！”：维克多·欧尔班在玛丽娜·勒庞被判刑和丧失参选资格后表示支持https://t.…
# RT @LeLapinDuFutur: 马琳·勒庞在斋月结束后的第二天被取消资格，那天我们看到数百万穆斯林在街上祈祷…
# RT @auriverdebrasil: 🚨玛丽娜·勒庞被判刑在法国引发政治影响及国际反应 🇫🇷‼️
#
# 司法判决了这位领导人…
# RT @Frontieresmedia: 🚨 最高司法委员会谴责“激烈的反应”和“对法官的威胁”…
# RT @RadioGenoa: 玛丽娜·勒庞：“这是一个政治决定。” https://t.co/vMrzo7WUqc
# RT @UpdateNews724: 🚨🇮🇹🇫🇷🇪🇺意大利副总理：
#
# 对玛丽娜·勒庞的所作所为是布鲁塞尔的宣战。
#
# 我们不会被吓倒…
# RT @ConflictTR: 🔴 挪用欧盟资金的法国政客玛丽娜·勒庞被判处4年监禁，并被施加政治禁令…
# 转发 @_MaxLoisel: 他们称之为“政变”👇
#
# - 玛丽娜·勒庞在TF1
#
# - 乔丹·巴尔代拉在CNews和欧洲1台
#
# - 菲利普·巴拉德…
# 转发@_MaxLoisel：他们称之为“政变”👇
#
# - 玛丽娜·勒庞在TF1
#
# - 乔丹·巴尔代拉在CNews和欧洲1台
#
# - 菲利普·巴拉德…
# RT @EvaVlaar: 针对欧洲右翼的法律战正在被提升到一个全新的水平。
#
# 玛丽娜·勒庞 @MLP_officiel 已被判决…
# RT @ChaRocher: 当然，没有人能凌驾于法律之上，然而针对被指控同样罪名的让-吕克·梅朗雄的调查进展如何…
# RT @BRICSinfo: 最新消息：🇮🇹 意大利副总理表示，“禁止玛丽娜·勒庞是布鲁塞尔的宣战声明。” https://t.co/q…
# RT @dupontaignan: 马琳·勒庞立即丧失参选资格，质疑了所有被告上诉的基本权利。这种双重标准…
# @EmmanuelMacron
# 与法官达成协议，以确保玛丽娜·勒庞在对他投不信任票时犹豫不决，因为她可能无法再次当选
# #hdpros2
# 转发 @cmgorriaran: 玛丽娜·勒庞的禁令已经被解读为司法骗局。极化已经摧毁了一切，…
# RT @robbystarbuck: 如果今天举行选举，玛丽娜·勒庞目前是法国下任总统的领先者。那么……
# RT @Benramine_: 菲利普·普图这个有远见的人，他在菲永和玛丽娜·勒庞的问题上是对的，真是个传奇 https://t.co/FEeEs85w0i
# RT @MLP_officiel：玛丽娜·勒庞受邀参加TF1的20H节目 https://t.co/An8FjvjdjW
# RT @TF1Info: 🔴 玛丽娜·勒庞 (@MLP_officiel) 受邀参加20点新闻
#
# 🗣️ "法庭主席的动机很明确：'我不……
# RT @KSzymanskiKonf: 对玛丽娜·勒庞的判决❗ 法国的民主终结了吗❓
#
# 👉 https://t.co/nNCKDbv8bS 👈
#
# 法国法院打击玛丽娜·勒庞…
# RT @Le_Patoff: 无论我们是否喜欢玛丽娜·勒庞
#
# 这种临时执行是对我们民主的绝对耻辱。
#
# 这是一次……
# 转发 @FredGaulois: Gilles Bouleau 面对玛丽娜·勒庞简直让人无法忍受，我们可以清楚地看到他的仇恨，他应该闭嘴面对…
# RT @CapitanBitcoin: 🚨🇫🇷 玛丽娜·勒庞，2027年的热门人选，刚刚被取消了5年的资格。快速判决，完美时机，还有一丝法律战的味道……
# 转发 @Bruno_Attal_：玛丽娜·勒庞的定罪确实是政治性的！
#
# 判决玛丽娜·勒庞的法官是贝内迪克特·德·佩尔蒂斯…
# RT @Inevitablewest: 🚨突发新闻：意大利副总理：
#
# “禁止玛丽娜·勒庞是布鲁塞尔的宣战声明。”
#
# 欧盟不知道……

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""rewrite the tweets delimited by {delimiter} in the tone like Stewie """},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# Ah, yes, GLOBALISM, that delightful little game where any leader with the audacity to ruffle the feathers of the establishment finds themselves in a rather unfortunate predicament—prosecution, imprisonment, or perhaps a charming little exile. How utterly predictable.
# RT @MrPitbull07: @MLP_officiel Oh, the irony! When democracy, that supposed bastion of freedom, decides to play dress-up as tyranny, all in the name of justice. How delightfully absurd! Marine Le Pen w…
# RT @morandiniblog: Oh, how utterly delightful! Marine Le Pen on TF1: "I simply cannot trust the date of the appeal, for it is not I who holds the reins of such matters..."
# The French court takes a swing at dear Marine Le Pe...
# RT @Le_Patoff: Whether one fancies Marine Le Pen or not, this temporary execution is an utter disgrace to our democracy. It's a dastardly blow to the very fabric of our society...
# RT @FredGaulois: Oh, the audacity of Gilles Bouleau when facing Marine Le Pen is simply intolerable. One can practically see the disdain oozing from his pores. Would it be too much to ask for him to just zip it for once?
# RT @CapitanBitcoin: 🚨🇫🇷 Oh, the delightful chaos! Marine Le Pen, the darling of 2027, has been sidelined for five years. A swift verdict, impeccable timing, and the unmistakable stench of legal shenanigans...
# RT @Bruno_Attal_: Oh, the condemnation of Marine Le Pen is positively dripping with political intrigue, isn't it? Bénédicte de Perthuis, the magistrate who orchestrated this little drama, is quite the character, wouldn't you say?
# RT @Inevitablewest: 🚨BREAKING: Italian Deputy PM:
#
# "Oh, how delightfully dramatic! Banning Marine Le Pen is akin to declaring war from Brussels, is it? My, my, the EU seems to have stirred quite the pot, haven’t they? One wonders if they truly comprehend the magnitude of their actions..."

# %% [markdown]
# ### Inferring
# - Use step-by-step instructions with delimiters to:
#   1. Identify sentiments
#   2. Identify emotions
#   3. Extract mentioned people's names
#   3. Identify whether a tweet supports Democratic, Republican, or unknown
#   4. Extract outputs into a structured JSON document.
# - Identify topics from Tweets.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a single word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    print(openai_help(messages))
# Out:
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Artemisfornow"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@MrPitbull07", "@MLP_officiel", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "distrust",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["HansMahncke", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["tavoliakys", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["bennyjohnson", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["Inevitablewest", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["PGKroeger", "Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["EvaVlaar", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "support",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "Marine Le Pen"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Gilles Bouleau", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Inevitablewest", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "surprise",
#   "mentioned": ["knafo_sarah"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["MarioNawfal", "Matteo Salvini", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["liz_churchill10", "Marine Le Pen", "Macron"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Fillon", "Sarkozy", "C8", "Zemmour", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": [
#     "philippeherlin",
#     "Eva Joly"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["Marine Le Pen", "Emmanuel Macron"],
#   "support": "none"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["YourAnonCentral", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "surprise",
#   "mentioned": ["PeterSweden7", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "nostalgia",
#   "mentioned": ["MedvedevRussiaE"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "supportive",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["JordanFlrtn", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Dmitri Medvedev", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "surprise",
#   "mentioned": ["knafo_sarah"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["Marine Le Pen", "Benjam1Lucas"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Artemisfornow"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["TimesAlgebraIND", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["EvaVlaar", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["@RadioRadioWeb", "@boni_castellane"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "sarcasm",
#   "mentioned": ["Marine Le Pen", "Vladimir Poutine", "Viktor Orban", "Elon Musk", "kim jong un"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "trust",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "support",
#   "mentioned": [
#     "Marine Le Pen"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": [
#     "PatrioteEngager",
#     "Bénédicte de Perthuis",
#     "Marine Le Pen"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["JD Vance", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Laure Lavalette", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "Bruno_Attal_",
#     "Marine Le Pen",
#     "Bénédicte de Perthuis"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "uncertainty",
#   "mentioned": ["PeterSweden7", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["liz_churchill10", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "shock",
#   "mentioned": ["Jean-Luc Mélenchon", "Geoffroy Lejeune"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "TolergueNina",
#     "Marine Le Pen"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["Kevin Maguire", "Marine Le Pen"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "defensive",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Elon Musk", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["ZeClint", "marine le pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["Michel Onfray", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["liz_churchill10", "Marine Le Pen", "Macron"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "uncertain",
#   "mentioned": ["@FouratiJerbi"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Fillon", "Sarkozy", "C8", "Zemmour", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["@BonneDroite", "@tegnererik", "Marine Le Pen"],
#   "support": "none"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Fillon", "Sarkozy", "C8", "Zemmour", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["AudeJavel79", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "Eva Joly",
#     "Bénédicte de Perthuis",
#     "Marine Le Pen"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "support",
#   "mentioned": ["Viktor Orban", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["Marine Le Pen"],
#   "support": "none"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Frontieresmedia"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "Marine Le Pen",
#     "Jordan Bardella",
#     "Philippe Ballard"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "Marine Le Pen",
#     "Jordan Bardella",
#     "Philippe Ballard"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["EvaVlaar", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": [
#     "Jean-Luc Mélenchon"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "suspicion",
#   "mentioned": ["Emmanuel Macron", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["cmgorriaran", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Marine Le Pen", "robbystarbuck"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "admiration",
#   "mentioned": ["Phillipe Poutou", "Fillion", "Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["Marine Le Pen"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["Gilles Bouleau", "Marine Le Pen"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Marine Le Pen"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": [
#     "Bruno_Attal_",
#     "Marine Le Pen",
#     "Bénédicte de Perthuis"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["Inevitablewest", "Marine Le Pen"],
#   "support": "neutral"
# }

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} to identify 10 topics, 
                                  Do not wrap the json codes in JSON markers """},
        {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter} "}]
print(openai_help(messages))
# Out:
# {
#   "1": "Marine Le Pen's Conviction",
#   "2": "Embezzlement Charges",
#   "3": "Political Ineligibility",
#   "4": "Reactions from International Leaders",
#   "5": "Impact on French Politics",
#   "6": "Criticism of Judicial System",
#   "7": "Globalism and Political Persecution",
#   "8": "Support for Marine Le Pen",
#   "9": "Media Coverage and Public Opinion",
#   "10": "Comparisons to Other Political Figures"
# }

# %% [markdown]
# ### Expanding with multiple prompts
# - Identify which party receives majority supports
# - Provide contexts in the system message
# - Create a chatbot to answer users’ inquiry

# %%
analysis_result = []
from tqdm import tqdm
for tweet in tqdm(tweet_data):
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a singple word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    analysis_result.append(openai_help(messages))
# Out:
# 100%|██████████| 100/100 [01:52<00:00,  1.13s/it]

# %%
print(analysis_result)
# Out:
# ['{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["Artemisfornow"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["MrPitbull07", "MLP_officiel", "Marine Le Pen"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "distrust",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["HansMahncke", "Marine Le Pen"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["tavoliakys", "Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["bennyjohnson", "Marine Le Pen"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "anger",\n  "mentioned": ["Inevitablewest", "Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "indifference",\n  "mentioned": ["PGKroeger", "Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "concern",\n  "mentioned": ["Eva Vlaar", "Marine Le Pen"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "outrage",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "none",\n  "mentioned": ["Marine Le Pen"],\n  "support": "none"\n}', '{\n  "sentiment": "negative",\n  "emotion": "outrage",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "support",\n  "mentioned": ["Marine Le Pen"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "disapproval",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Gilles Bouleau", "Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "indifference",\n  "mentioned": [\n    "Marine Le Pen"\n  ],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "surprise",\n  "mentioned": ["knafo_sarah"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "outrage",\n  "mentioned": ["MarioNawfal", "Matteo Salvini", "Marine Le Pen"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "rejection",\n  "mentioned": ["liz_churchill10", "Marine Le Pen", "Macron"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["Fillon", "Sarkozy", "C8", "Zemmour", "Marine Le Pen"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "none",\n  "mentioned": [\n    "philippeherlin",\n    "Eva Joly"\n  ],\n  "support": "none"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Marine Le Pen", "Emmanuel Macron"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "indifference",\n  "mentioned": ["YourAnonCentral", "Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "surprise",\n  "mentioned": ["Marine Le Pen", "PeterSweden7"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Marine Le Pen"],\n  "support": "neutral"\n}', '{\n  " ...

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet analysis reuslt delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} count the number of tweets that support Democratic and Republican;
                                        step 2 {delimiter} identify the common sentiments and emotoions to each mentioned people;
                                        step 3 {delimiter} organize the result in a json document with keys <Democratic count>, <Republican count>, <people name>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{analysis_result}{delimiter} "}]
analysis_summary = openai_help(messages)
print(analysis_summary)
# Out:
# {
#   "Democratic count": 2,
#   "Republican count": 23,
#   "people name": {
#     "Artemisfornow": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "MrPitbull07": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "MLP_officiel": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "Marine Le Pen": {
#       "sentiments": ["negative", "neutral", "positive"],
#       "emotions": ["frustration", "distrust", "informative", "anger", "indifference", "concern", "outrage", "disapproval", "rejection", "defiance", "support", "surprise", "curiosity", "sarcasm", "trust", "shock", "suspicion", "admiration"]
#     },
#     "HansMahncke": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "tavoliakys": {
#       "sentiments": ["neutral"],
#       "emotions": ["informative"]
#     },
#     "bennyjohnson": {
#       "sentiments": ["neutral"],
#       "emotions": ["informative"]
#     },
#     "Inevitablewest": {
#       "sentiments": ["negative"],
#       "emotions": ["anger"]
#     },
#     "PGKroeger": {
#       "sentiments": ["neutral"],
#       "emotions": ["indifference"]
#     },
#     "Eva Vlaar": {
#       "sentiments": ["negative"],
#       "emotions": ["concern"]
#     },
#     "knafo_sarah": {
#       "sentiments": ["neutral"],
#       "emotions": ["surprise"]
#     },
#     "MarioNawfal": {
#       "sentiments": ["negative"],
#       "emotions": ["outrage"]
#     },
#     "Matteo Salvini": {
#       "sentiments": ["negative"],
#       "emotions": ["outrage"]
#     },
#     "liz_churchill10": {
#       "sentiments": ["negative"],
#       "emotions": ["rejection"]
#     },
#     "Macron": {
#       "sentiments": ["negative"],
#       "emotions": ["rejection"]
#     },
#     "Fillon": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "Sarkozy": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "C8": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "Zemmour": {
#       "sentiments": ["negative"],
#       "emotions": ["frustration"]
#     },
#     "philippeherlin": {
#       "sentiments": ["neutral"],
#       "emotions": ["none"]
#     },
#     "Eva Joly": {
#       "sentiments": ["neutral"],
#       "emotions": ["none"]
#     },
#     "Emmanuel Macron": {
#       "sentiments": ["neutral"],
#       "emotions": ["suspicion"]
#     },
#     "YourAnonCentral": {
#       "sentiments": ["neutral"],
#       "emotions": ["indifference"]
#     },
#     "PeterSweden7": {
#       "sentiments": ["neutral"],
#       "emotions": ["surprise"]
#     },
#     "MedvedevRussiaE": {
#       "sentiments": ["neutral"],
#       "emotions": ["nostalgic"]
#     },
#     "JordanFlrtn": {
#       "sentiments": ["neutral"],
#       "emotions": ["concern"]
#     },
#     "Dmitri Medvedev": {
#       "sentiments": ["neutral"],
#       "emotions": ["concern"]
#     },
#     "Benjam1Lucas": {
#       "sentiments": ["negative"],
#       "emotions": ["disapproval"]
#     },
#     "Vladimir Poutine": {
#       "sentiments": ["neutral"],
#       "emotions": ["sarcasm"]
#     },
#     "Viktor Orban": {
#       "sentiments": ["neutral"],
#       "emotions": ["supportive"]
#     },
#     "Elon Musk": {
#       "sentiments": ["neutral"],
#       "emotions": ["concern"]
#     },
#     "kim jong un": {
#       "sentiments": ["neutral"],
#       "emotions": ["sarcasm"]
#     },
#     "Bénédicte de Perthuis": {
#       "sentiments": ["negative"],
#       "emotions": ["anger"]
#     },
#     "JD Vance": {
#       "sentiments": ["neutral"],
#       "emotions": ["informative"]
#     },
#     "LaureLavalette": {
#       "sentiments": ["neutral"],
#       "emotions": ["informative"]
#     },
#     "Bruno_Attal_": {
#       "sentiments": ["negative"],
#       "emotions": ["outrage"]
#     },
#     "Jean-Luc Mélenchon": {
#       "sentiments": ["neutral"],
#       "emotions": ["curiosity"]
#     },
#     "Geoffroy Lejeune": {
#       "sentiments": ["neutral"],
#       "emotions": ["shock"]
#     },
#     "Kevin_Maguire": {
#       "sentiments": ["negative"],
#       "emotions": ["disapproval"]
#     },
#     "ZeClint": {
#       "sentiments": ["neutral"],
#       "emotions": ["concern"]
#     },
#     "robbystarbuck": {
#       "sentiments": ["neutral"],
#       "emotions": ["informative"]
#     },
#     "Phillipe Poutou": {
#       "sentiments": ["positive"],
#       "emotions": ["admiration"]
#     },
#     "Frontieresmedia": {
#       "sentiments": ["negative"],
#       "emotions": ["concern"]
#     },
#     "Michel Onfray": {
#       "sentiments": ["neutral"],
#       "emotions": ["none"]
#     }
#   }
# }

# %% [markdown]
# ## Create a chatbot

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

chat_history = [

{"role": "system", "content": f"""you are a chabot answer user questions based on the tweets,
                                {delimiter}{tweet_data}{delimiter}, 
                                if user mentioned a people name in the {delimiter}{analysis_summary}{delimiter} people field,report the corresponding sentiment and emotion,
                            
                            """}
]

def chatbot(prompt):

    chat_history.append({"role": "user", "content": prompt})

    response = client.chat.completions.create(
        model=model,  # Use the model you prefer
        messages=chat_history
    )

    reply = response.choices[0].message.content

    chat_history.append({"role": "assistant", "content": reply})
    
    return reply

# %%
while True:
    user_input = input("You: ")
    if user_input.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye!")
        break
    reply = chatbot(user_input)
    print(f"Chatbot: {reply}")
# Out:
# You:  thanks
# Chatbot: You're welcome! If you have any other questions or need further information, feel free to ask.

# %% [markdown]
# ## Reference
# - Isa Fulford and Andrew Ng. n.d.-a. *“Building Systems with the ChatGPT API.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/building-systems-with-chatgpt/.
# - ———. n.d.-b. *“ChatGPT Prompt Engineering for Developers.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/chatgpt-prompt-engineering-for-developers/.
# - OpenAI. n.d. *“OpenAI Documents.”* OpenAI. Accessed October 18, 2024. https://platform.openai.com.
